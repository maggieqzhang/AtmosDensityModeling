# %%
from keras.layers import Input, Dense, Activation, Dropout, LeakyReLU, Lambda, PReLU
from keras.models import Model, Sequential, model_from_json
from matplotlib.backends.backend_pdf import PdfPages
from keras.callbacks import EarlyStopping
from keras import optimizers, activations, regularizers
from keras import backend as K
from sklearn.model_selection import train_test_split, KFold
from numpy import loadtxt
from keras.models import load_model, model_from_json
from keras.backend import sigmoid
from keras.utils.generic_utils import get_custom_objects
import json
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import h5py

# %%
class Swish(Activation):
    
    def __init__(self, activation, **kwargs):
        super(Swish, self).__init__(activation, **kwargs)
        self.__name__ = 'swish'

def swish(x):
    return (sigmoid(x) * x)

get_custom_objects().update({'swish': Swish(swish)})

# %%
'''1x1 filter'''
with open('/Users/maggiezhang/Dropbox/AtmosphereMachineLearning/DensityData/Models/1x1final12.json','r') as f:
    model_encoder_json = json.load(f)
    model_encoder_json = json.dumps(model_encoder_json)
    model_encoder_json = str(model_encoder_json)

model_encoder = model_from_json(model_encoder_json)
#weights =h5py.File('/Users/maggiezhang/Desktop/1x1filter120.h5', 'r')
model_encoder.load_weights('/Users/maggiezhang/Desktop/1x1filter120.h5')
model_encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 24, 20, 36, 1)     0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 24, 20, 1, 795)    29415
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 20, 1, 795)    96
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 24, 1, 1, 204)     3243804
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 1, 1, 204)     96
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 1, 1, 1, 934)      4573798
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 1, 934)      4
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 934)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                9350
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                231
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 21)                84
# _________________________________________________________________
# dense_3 (Dense)              (None, 45)                990
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 45)                180
# _________________________________________________________________
# dense_4 (Dense)              (None, 97)                4462
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 97)                388
# _________________________________________________________________
# dense_5 (Dense)              (None, 210)               20580
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 210)               840
# _________________________________________________________________
# dense_6 (Dense)              (None, 455)               96005
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 455)               1820
# _________________________________________________________________
# dense_7 (Dense)              (None, 987)               450072
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 987)               3948
# _________________________________________________________________
# dense_8 (Dense)              (None, 2141)              2115308
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2141)              8564
# _________________________________________________________________
# dense_9 (Dense)              (None, 4645)              9949590
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4645)              18580
# _________________________________________________________________
# dense_10 (Dense)             (None, 10078)             46822388
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 10078)             40312
# _________________________________________________________________
# dense_11 (Dense)             (None, 17280)             174165120
# =================================================================
# Total params: 241,556,025
# Trainable params: 241,518,569
# Non-trainable params: 37,456
# _________________________________________________________________

# %%
encoder_model_1x1 = Model(inputs=model_encoder.input, outputs=model_encoder.layers[8].output)
encoder_model_1x1.summary()

decode_input = Input(model_encoder.layers[9].input_shape[1:])
decoder_model_1x1 = decode_input
for layer in model_encoder.layers[9:]:
    decoder_model_1x1 = layer(decoder_model_1x1)
decoder_model_1x1 = Model(inputs=decode_input, outputs=decoder_model_1x1)

decoder_model_1x1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 24, 20, 36, 1)     0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 24, 20, 1, 795)    29415
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 20, 1, 795)    96
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 24, 1, 1, 204)     3243804
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 1, 1, 204)     96
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 1, 1, 1, 934)      4573798
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 1, 934)      4
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 934)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                9350
# =================================================================
# Total params: 7,856,563
# Trainable params: 7,856,465
# Non-trainable params: 98
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                231
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 21)                84
# _________________________________________________________________
# dense_3 (Dense)              (None, 45)                990
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 45)                180
# _________________________________________________________________
# dense_4 (Dense)              (None, 97)                4462
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 97)                388
# _________________________________________________________________
# dense_5 (Dense)              (None, 210)               20580
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 210)               840
# _________________________________________________________________
# dense_6 (Dense)              (None, 455)               96005
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 455)               1820
# _________________________________________________________________
# dense_7 (Dense)              (None, 987)               450072
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 987)               3948
# _________________________________________________________________
# dense_8 (Dense)              (None, 2141)              2115308
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2141)              8564
# _________________________________________________________________
# dense_9 (Dense)              (None, 4645)              9949590
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4645)              18580
# _________________________________________________________________
# dense_10 (Dense)             (None, 10078)             46822388
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 10078)             40312
# _________________________________________________________________
# dense_11 (Dense)             (None, 17280)             174165120
# =================================================================
# Total params: 233,699,462
# Trainable params: 233,662,104
# Non-trainable params: 37,358
# _________________________________________________________________

# %%
xdata= np.load("NRLMSISE_concat_data.npy")
xdata_1 = np.log10(xdata)
xmat = (xdata_1 - np.mean(xdata_1, keepdims=True)) / np.std(xdata_1, keepdims=True)
xmat = np.reshape(xmat, (105192, 24, 20, 36, 1))
full_sw = scipy.io.loadmat("/Users/maggiezhang/Dropbox/AtmosphereMachineLearning/DensityData/SWdata_NRLMSISE_1997_2008_smooth.mat")
full_sw = full_sw['SWdataFullSmooth']
print(full_sw.shape)
# Out:
# (105192, 11)

# %%
dens_data = encoder_model_1x1.predict(xmat)
print(dens_data.shape)
# Out:
# (105192, 10)

# %%
sw_data = full_sw
pred_number = 24

# Only consider first 10 modes/dimensions of reduced data
dens_data = dens_data[:,0:10]

'''Training data'''
# Training input

split_15 = int(dens_data.shape[0]*0.85) # manual test split 

dens_data_train = dens_data[0:split_15-pred_number,:]
sw_data_train = sw_data[0:split_15-pred_number,:]
sw_data_train_append = sw_data[1:split_15-pred_number+1,:] #looks at next sw timestep because it could be useful in prediction 
sw_data_train = np.concatenate((sw_data_train, sw_data_train_append), axis=1)
# Input is reduced-order density and space weather data
x_train = np.concatenate((dens_data_train, sw_data_train), axis=1)
# Training output
y_train = dens_data[1:split_15-pred_number+1,:]

'''ROM LINEAR MATRICES''' 
Om = np.append(np.transpose(dens_data_train), np.transpose(sw_data_train), axis = 0)
X2 = np.transpose(y_train)

# Compute dynamic matrices:
# Phi = X2*pinv(Om)
Phi = np.matmul(X2,np.linalg.pinv(Om))

r = 10 #reduced order 
A = Phi[:r, :r]
B = Phi[:r, r:]

'''Test data'''
# Test input
dens_data_test = dens_data[split_15-pred_number-1:-pred_number-2,:]
sw_data_test = sw_data[split_15-pred_number-1:-pred_number-2,:]
sw_data_test_append = sw_data[split_15-pred_number:-pred_number-1,:]
sw_data_test = np.concatenate((sw_data_test, sw_data_test_append), axis = 1)
# Input is reduced-order density and space weather data
x_test = np.concatenate((dens_data_test, sw_data_test), axis=1)

# Test output
y_test = dens_data[split_15-pred_number:-pred_number-1,:]

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.17647) #, random_state=42)

# %%
model = Sequential()
model.add(Dense(120, kernel_initializer='random_uniform'))
model.add(LeakyReLU(alpha=0.3))
model.add(Dense(40, kernel_initializer='random_uniform'))
model.add(LeakyReLU(alpha=0.3))
model.add(Dense(20, kernel_initializer='random_uniform'))
model.add(LeakyReLU(alpha=0.3))
model.add(Dense(10, kernel_initializer='random_uniform'))
ad = optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(optimizer=ad, loss='mse', metrics=['accuracy'])

# %%
history = model.fit(x = x_train, y = y_train, validation_data = (x_val, y_val), epochs = 500, batch_size = 32)
# Out:
# Train on 73614 samples, validate on 15775 samples
# Epoch 1/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0043 - val_accuracy: 0.9969
# Epoch 2/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0042 - accuracy: 0.9972 - val_loss: 0.0036 - val_accuracy: 0.9968
# Epoch 3/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0041 - accuracy: 0.9972 - val_loss: 0.0061 - val_accuracy: 0.9978
# Epoch 4/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0040 - accuracy: 0.9970 - val_loss: 0.0044 - val_accuracy: 0.9971
# Epoch 5/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0043 - accuracy: 0.9973 - val_loss: 0.0087 - val_accuracy: 0.9977
# Epoch 6/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0041 - accuracy: 0.9972 - val_loss: 0.0074 - val_accuracy: 0.9968
# Epoch 7/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0041 - accuracy: 0.9970 - val_loss: 0.0040 - val_accuracy: 0.9968
# Epoch 8/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0043 - accuracy: 0.9971 - val_loss: 0.0047 - val_accuracy: 0.9977
# Epoch 9/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0041 - accuracy: 0.9974 - val_loss: 0.0034 - val_accuracy: 0.9984
# Epoch 10/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0040 - accuracy: 0.9970 - val_loss: 0.0028 - val_accuracy: 0.9980
# Epoch 11/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0041 - accuracy: 0.9971 - val_loss: 0.0043 - val_accuracy: 0.9967
# Epoch 12/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9973 - val_loss: 0.0034 - val_accuracy: 0.9984
# Epoch 13/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0043 - accuracy: 0.9970 - val_loss: 0.0101 - val_accuracy: 0.9970
# Epoch 14/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0040 - accuracy: 0.9971 - val_loss: 0.0040 - val_accuracy: 0.9966
# Epoch 15/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0026 - val_accuracy: 0.9985
# Epoch 16/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0026 - val_accuracy: 0.9987
# Epoch 17/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0041 - accuracy: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9969
# Epoch 18/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0029 - val_accuracy: 0.9978
# Epoch 19/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9970 - val_loss: 0.0058 - val_accuracy: 0.9973
# Epoch 20/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0047 - val_accuracy: 0.9977
# Epoch 21/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0045 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 22/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0044 - val_accuracy: 0.9972
# Epoch 23/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9970 - val_loss: 0.0033 - val_accuracy: 0.9973
# Epoch 24/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0041 - accuracy: 0.9973 - val_loss: 0.0031 - val_accuracy: 0.9985
# Epoch 25/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0040 - accuracy: 0.9973 - val_loss: 0.0031 - val_accuracy: 0.9983
# Epoch 26/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0032 - val_accuracy: 0.9981
# Epoch 27/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0041 - accuracy: 0.9973 - val_loss: 0.0028 - val_accuracy: 0.9985
# Epoch 28/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0053 - val_accuracy: 0.9970
# Epoch 29/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0041 - accuracy: 0.9972 - val_loss: 0.0037 - val_accuracy: 0.9978
# Epoch 30/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0047 - val_accuracy: 0.9982
# Epoch 31/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0043 - accuracy: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9978
# Epoch 32/500
# 73614/73614 [==============================] - 2s 34us/step - loss: 0.0040 - accuracy: 0.9974 - val_loss: 0.0035 - val_accuracy: 0.9980
# Epoch 33/500
# 73614/73614 [==============================] - 2s 34us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9978
# Epoch 34/500
# 73614/73614 [==============================] - 3s 37us/step - loss: 0.0041 - accuracy: 0.9972 - val_loss: 0.0034 - val_accuracy: 0.9985
# Epoch 35/500
# 73614/73614 [==============================] - 3s 38us/step - loss: 0.0041 - accuracy: 0.9974 - val_loss: 0.0031 - val_accuracy: 0.9977
# Epoch 36/500
# 73614/73614 [==============================] - 3s 38us/step - loss: 0.0041 - accuracy: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9963
# Epoch 37/500
# 73614/73614 [==============================] - 3s 38us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9980
# Epoch 38/500
# 73614/73614 [==============================] - 3s 37us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9974
# Epoch 39/500
# 73614/73614 [==============================] - 3s 37us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0034 - val_accuracy: 0.9978
# Epoch 40/500
# 73614/73614 [==============================] - 3s 35us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0214 - val_accuracy: 0.9929
# Epoch 41/500
# 73614/73614 [==============================] - 3s 34us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9983
# Epoch 42/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0034 - val_accuracy: 0.9977
# Epoch 43/500
# 73614/73614 [==============================] - 2s 33us/step - loss: 0.0040 - accuracy: 0.9974 - val_loss: 0.0035 - val_accuracy: 0.9975
# Epoch 44/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0023 - val_accuracy: 0.9983
# Epoch 45/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0039 - val_accuracy: 0.9972
# Epoch 46/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0041 - accuracy: 0.9973 - val_loss: 0.0035 - val_accuracy: 0.9977
# Epoch 47/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0084 - val_accuracy: 0.9980
# Epoch 48/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0041 - accuracy: 0.9974 - val_loss: 0.0026 - val_accuracy: 0.9982
# Epoch 49/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0030 - val_accuracy: 0.9972
# Epoch 50/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0041 - accuracy: 0.9972 - val_loss: 0.0037 - val_accuracy: 0.9971
# Epoch 51/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0041 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 0.9979
# Epoch 52/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0038 - accuracy: 0.9973 - val_loss: 0.0034 - val_accuracy: 0.9980
# Epoch 53/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0117 - val_accuracy: 0.9972
# Epoch 54/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0043 - val_accuracy: 0.9978
# Epoch 55/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0198 - val_accuracy: 0.9959
# Epoch 56/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0037 - val_accuracy: 0.9982
# Epoch 57/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9978
# Epoch 58/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9972 - val_loss: 0.0036 - val_accuracy: 0.9974
# Epoch 59/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0058 - val_accuracy: 0.9971
# Epoch 60/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0026 - val_accuracy: 0.9980
# Epoch 61/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0038 - val_accuracy: 0.9975
# Epoch 62/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0063 - val_accuracy: 0.9973
# Epoch 63/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0042 - accuracy: 0.9974 - val_loss: 0.0035 - val_accuracy: 0.9964
# Epoch 64/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 0.9983
# Epoch 65/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 0.0050 - val_accuracy: 0.9970
# Epoch 66/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 67/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0043 - accuracy: 0.9974 - val_loss: 0.0050 - val_accuracy: 0.9966
# Epoch 68/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 69/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0041 - accuracy: 0.9969 - val_loss: 0.0043 - val_accuracy: 0.9979
# Epoch 70/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0042 - accuracy: 0.9971 - val_loss: 0.0029 - val_accuracy: 0.9980
# Epoch 71/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0039 - val_accuracy: 0.9964
# Epoch 72/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0094 - val_accuracy: 0.9965
# Epoch 73/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0040 - accuracy: 0.9974 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 74/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0044 - val_accuracy: 0.9978
# Epoch 75/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0040 - val_accuracy: 0.9976
# Epoch 76/500
# 73614/73614 [==============================] - 2s 33us/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 0.0028 - val_accuracy: 0.9985
# Epoch 77/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0033 - val_accuracy: 0.9977
# Epoch 78/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 79/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9984
# Epoch 80/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9976 - val_loss: 0.0053 - val_accuracy: 0.9973
# Epoch 81/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0042 - accuracy: 0.9975 - val_loss: 0.0054 - val_accuracy: 0.9978
# Epoch 82/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0040 - val_accuracy: 0.9980
# Epoch 83/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0094 - val_accuracy: 0.9955
# Epoch 84/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0038 - accuracy: 0.9973 - val_loss: 0.0031 - val_accuracy: 0.9980
# Epoch 85/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0028 - val_accuracy: 0.9990
# Epoch 86/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0042 - accuracy: 0.9975 - val_loss: 0.0055 - val_accuracy: 0.9961
# Epoch 87/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 0.0019 - val_accuracy: 0.9989
# Epoch 88/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 89/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0044 - val_accuracy: 0.9975
# Epoch 90/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0028 - val_accuracy: 0.9989
# Epoch 91/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0034 - val_accuracy: 0.9972
# Epoch 92/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0023 - val_accuracy: 0.9985
# Epoch 93/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0040 - accuracy: 0.9973 - val_loss: 0.0040 - val_accuracy: 0.9974
# Epoch 94/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0084 - val_accuracy: 0.9973
# Epoch 95/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0028 - val_accuracy: 0.9984
# Epoch 96/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.0025 - val_accuracy: 0.9979
# Epoch 97/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0049 - val_accuracy: 0.9987
# Epoch 98/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0038 - accuracy: 0.9976 - val_loss: 0.0039 - val_accuracy: 0.9982
# Epoch 99/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0035 - val_accuracy: 0.9982
# Epoch 100/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0041 - accuracy: 0.9975 - val_loss: 0.0103 - val_accuracy: 0.9970
# Epoch 101/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9983
# Epoch 102/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0038 - accuracy: 0.9976 - val_loss: 0.0026 - val_accuracy: 0.9982
# Epoch 103/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0027 - val_accuracy: 0.9972
# Epoch 104/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9978
# Epoch 105/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0040 - accuracy: 0.9973 - val_loss: 0.0073 - val_accuracy: 0.9971
# Epoch 106/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9979
# Epoch 107/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0028 - val_accuracy: 0.9987
# Epoch 108/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9978
# Epoch 109/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0042 - val_accuracy: 0.9983
# Epoch 110/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9986
# Epoch 111/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 0.9985
# Epoch 112/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0090 - val_accuracy: 0.9951
# Epoch 113/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0037 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9990
# Epoch 114/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9975
# Epoch 115/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9973
# Epoch 116/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9986
# Epoch 117/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0046 - val_accuracy: 0.9980
# Epoch 118/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9973 - val_loss: 0.0106 - val_accuracy: 0.9953
# Epoch 119/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0041 - val_accuracy: 0.9986
# Epoch 120/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0045 - val_accuracy: 0.9970
# Epoch 121/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0090 - val_accuracy: 0.9973
# Epoch 122/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.0047 - val_accuracy: 0.9982
# Epoch 123/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0030 - val_accuracy: 0.9984
# Epoch 124/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0065 - val_accuracy: 0.9951
# Epoch 125/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0032 - val_accuracy: 0.9982
# Epoch 126/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9982
# Epoch 127/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9978 - val_loss: 0.0028 - val_accuracy: 0.9987
# Epoch 128/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9983
# Epoch 129/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0046 - val_accuracy: 0.9972
# Epoch 130/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0036 - accuracy: 0.9973 - val_loss: 0.0043 - val_accuracy: 0.9986
# Epoch 131/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 0.0033 - val_accuracy: 0.9985
# Epoch 132/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0033 - accuracy: 0.9976 - val_loss: 0.0049 - val_accuracy: 0.9982
# Epoch 133/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0038 - accuracy: 0.9976 - val_loss: 0.0042 - val_accuracy: 0.9968
# Epoch 134/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9977 - val_loss: 0.0030 - val_accuracy: 0.9987
# Epoch 135/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9984
# Epoch 136/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0040 - accuracy: 0.9975 - val_loss: 0.0027 - val_accuracy: 0.9985
# Epoch 137/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9978
# Epoch 138/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0055 - val_accuracy: 0.9976
# Epoch 139/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0029 - val_accuracy: 0.9980
# Epoch 140/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9976
# Epoch 141/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9971 - val_loss: 0.0034 - val_accuracy: 0.9987
# Epoch 142/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0039 - accuracy: 0.9973 - val_loss: 0.0095 - val_accuracy: 0.9975
# Epoch 143/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0037 - accuracy: 0.9977 - val_loss: 0.0026 - val_accuracy: 0.9980
# Epoch 144/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0036 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9985
# Epoch 145/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9978
# Epoch 146/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 147/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0060 - val_accuracy: 0.9961
# Epoch 148/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0039 - val_accuracy: 0.9988
# Epoch 149/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0020 - val_accuracy: 0.9985
# Epoch 150/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0036 - accuracy: 0.9972 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 151/500
# 73614/73614 [==============================] - 3s 35us/step - loss: 0.0038 - accuracy: 0.9973 - val_loss: 0.0066 - val_accuracy: 0.9977
# Epoch 152/500
# 73614/73614 [==============================] - 3s 37us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0055 - val_accuracy: 0.9982
# Epoch 153/500
# 73614/73614 [==============================] - 3s 36us/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0036 - val_accuracy: 0.9984
# Epoch 154/500
# 73614/73614 [==============================] - 3s 36us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0058 - val_accuracy: 0.9971
# Epoch 155/500
# 73614/73614 [==============================] - 2s 33us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9977
# Epoch 156/500
# 73614/73614 [==============================] - 2s 32us/step - loss: 0.0036 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 0.9971
# Epoch 157/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 158/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9985
# Epoch 159/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0035 - val_accuracy: 0.9982
# Epoch 160/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0018 - val_accuracy: 0.9994
# Epoch 161/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0036 - val_accuracy: 0.9973
# Epoch 162/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 163/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9985
# Epoch 164/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0038 - accuracy: 0.9974 - val_loss: 0.0031 - val_accuracy: 0.9982
# Epoch 165/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0024 - val_accuracy: 0.9975
# Epoch 166/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0024 - val_accuracy: 0.9984
# Epoch 167/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9977 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 168/500
# 73614/73614 [==============================] - 12s 158us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0035 - val_accuracy: 0.9981
# Epoch 169/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0038 - val_accuracy: 0.9978
# Epoch 170/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0039 - accuracy: 0.9974 - val_loss: 0.0045 - val_accuracy: 0.9979
# Epoch 171/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9977 - val_loss: 0.0084 - val_accuracy: 0.9963
# Epoch 172/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0049 - val_accuracy: 0.9973
# Epoch 173/500
# 73614/73614 [==============================] - 2s 31us/step - loss: 0.0036 - accuracy: 0.9973 - val_loss: 0.0025 - val_accuracy: 0.9976
# Epoch 174/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0047 - val_accuracy: 0.9979
# Epoch 175/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0047 - val_accuracy: 0.9980
# Epoch 176/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9984
# Epoch 177/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0035 - accuracy: 0.9978 - val_loss: 0.0039 - val_accuracy: 0.9966
# Epoch 178/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0047 - val_accuracy: 0.9975
# Epoch 179/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0037 - val_accuracy: 0.9983
# Epoch 180/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0054 - val_accuracy: 0.9975
# Epoch 181/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0037 - val_accuracy: 0.9978
# Epoch 182/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9988
# Epoch 183/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 0.9990
# Epoch 184/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0027 - val_accuracy: 0.9977
# Epoch 185/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0035 - val_accuracy: 0.9977
# Epoch 186/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0062 - val_accuracy: 0.9978
# Epoch 187/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9972 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 188/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0031 - val_accuracy: 0.9984
# Epoch 189/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9975
# Epoch 190/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0038 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9985
# Epoch 191/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9977 - val_loss: 0.0037 - val_accuracy: 0.9982
# Epoch 192/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0043 - val_accuracy: 0.9984
# Epoch 193/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0044 - val_accuracy: 0.9982
# Epoch 194/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0030 - val_accuracy: 0.9984
# Epoch 195/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0034 - val_accuracy: 0.9987
# Epoch 196/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0037 - val_accuracy: 0.9980
# Epoch 197/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0041 - val_accuracy: 0.9977
# Epoch 198/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 199/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0038 - val_accuracy: 0.9977
# Epoch 200/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0064 - val_accuracy: 0.9971
# Epoch 201/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0062 - val_accuracy: 0.9973
# Epoch 202/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9977 - val_loss: 0.0036 - val_accuracy: 0.9977
# Epoch 203/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0039 - val_accuracy: 0.9984
# Epoch 204/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0021 - val_accuracy: 0.9986
# Epoch 205/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0022 - val_accuracy: 0.9987
# Epoch 206/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 207/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9971 - val_loss: 0.0029 - val_accuracy: 0.9984
# Epoch 208/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9987
# Epoch 209/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0039 - val_accuracy: 0.9980
# Epoch 210/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 0.9982
# Epoch 211/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0038 - accuracy: 0.9971 - val_loss: 0.0027 - val_accuracy: 0.9990
# Epoch 212/500
# 73614/73614 [==============================] - 2s 30us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9990
# Epoch 213/500
# 73614/73614 [==============================] - 2s 29us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9984
# Epoch 214/500
# 73614/73614 [==============================] - 2s 28us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0025 - val_accuracy: 0.9987
# Epoch 215/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9982
# Epoch 216/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0091 - val_accuracy: 0.9985
# Epoch 217/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0053 - val_accuracy: 0.9980
# Epoch 218/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0053 - val_accuracy: 0.9979
# Epoch 219/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0171 - val_accuracy: 0.9947
# Epoch 220/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0064 - val_accuracy: 0.9970
# Epoch 221/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0056 - val_accuracy: 0.9974
# Epoch 222/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9985
# Epoch 223/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0049 - val_accuracy: 0.9972
# Epoch 224/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0068 - val_accuracy: 0.9975
# Epoch 225/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9976 - val_loss: 0.0053 - val_accuracy: 0.9980
# Epoch 226/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9976
# Epoch 227/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9978 - val_loss: 0.0034 - val_accuracy: 0.9978
# Epoch 228/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9974 - val_loss: 0.0022 - val_accuracy: 0.9986
# Epoch 229/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0025 - val_accuracy: 0.9978
# Epoch 230/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9982
# Epoch 231/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9973 - val_loss: 0.0053 - val_accuracy: 0.9978
# Epoch 232/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0024 - val_accuracy: 0.9973
# Epoch 233/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.0062 - val_accuracy: 0.9962
# Epoch 234/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9974 - val_loss: 0.0036 - val_accuracy: 0.9973
# Epoch 235/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0022 - val_accuracy: 0.9984
# Epoch 236/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9973
# Epoch 237/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0036 - val_accuracy: 0.9984
# Epoch 238/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9976 - val_loss: 0.0022 - val_accuracy: 0.9985
# Epoch 239/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0022 - val_accuracy: 0.9987
# Epoch 240/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0035 - val_accuracy: 0.9989
# Epoch 241/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0033 - val_accuracy: 0.9987
# Epoch 242/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9979 - val_loss: 0.0039 - val_accuracy: 0.9973
# Epoch 243/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0018 - val_accuracy: 0.9987
# Epoch 244/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9981
# Epoch 245/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0033 - val_accuracy: 0.9973
# Epoch 246/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9975 - val_loss: 0.0038 - val_accuracy: 0.9967
# Epoch 247/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0042 - val_accuracy: 0.9970
# Epoch 248/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0050 - val_accuracy: 0.9972
# Epoch 249/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0027 - val_accuracy: 0.9979
# Epoch 250/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0023 - val_accuracy: 0.9990
# Epoch 251/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0036 - accuracy: 0.9977 - val_loss: 0.0029 - val_accuracy: 0.9971
# Epoch 252/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0134 - val_accuracy: 0.9954
# Epoch 253/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0035 - val_accuracy: 0.9970
# Epoch 254/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0073 - val_accuracy: 0.9968
# Epoch 255/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9978
# Epoch 256/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9983
# Epoch 257/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 0.9980
# Epoch 258/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0022 - val_accuracy: 0.9987
# Epoch 259/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0073 - val_accuracy: 0.9977
# Epoch 260/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0025 - val_accuracy: 0.9981
# Epoch 261/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0025 - val_accuracy: 0.9979
# Epoch 262/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0055 - val_accuracy: 0.9982
# Epoch 263/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0024 - val_accuracy: 0.9987
# Epoch 264/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.0059 - val_accuracy: 0.9974
# Epoch 265/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0039 - val_accuracy: 0.9963
# Epoch 266/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9987
# Epoch 267/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 268/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9978
# Epoch 269/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0055 - val_accuracy: 0.9977
# Epoch 270/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0023 - val_accuracy: 0.9987
# Epoch 271/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0028 - val_accuracy: 0.9984
# Epoch 272/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9981
# Epoch 273/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9975 - val_loss: 0.0061 - val_accuracy: 0.9970
# Epoch 274/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 0.9985
# Epoch 275/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0070 - val_accuracy: 0.9973
# Epoch 276/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9975
# Epoch 277/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9980 - val_loss: 0.0024 - val_accuracy: 0.9985
# Epoch 278/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0041 - val_accuracy: 0.9979
# Epoch 279/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0033 - val_accuracy: 0.9984
# Epoch 280/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 0.0031 - val_accuracy: 0.9982
# Epoch 281/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0024 - val_accuracy: 0.9988
# Epoch 282/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0068 - val_accuracy: 0.9959
# Epoch 283/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0037 - accuracy: 0.9975 - val_loss: 0.0023 - val_accuracy: 0.9985
# Epoch 284/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0021 - val_accuracy: 0.9987
# Epoch 285/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9979
# Epoch 286/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9982
# Epoch 287/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9979 - val_loss: 0.0037 - val_accuracy: 0.9981
# Epoch 288/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0025 - val_accuracy: 0.9983
# Epoch 289/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9973 - val_loss: 0.0022 - val_accuracy: 0.9987
# Epoch 290/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0039 - val_accuracy: 0.9985
# Epoch 291/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9976
# Epoch 292/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9986
# Epoch 293/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9979 - val_loss: 0.0023 - val_accuracy: 0.9979
# Epoch 294/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0032 - val_accuracy: 0.9977
# Epoch 295/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0029 - val_accuracy: 0.9982
# Epoch 296/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9979 - val_loss: 0.0023 - val_accuracy: 0.9991
# Epoch 297/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 0.0022 - val_accuracy: 0.9987
# Epoch 298/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0023 - val_accuracy: 0.9989
# Epoch 299/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9979 - val_loss: 0.0033 - val_accuracy: 0.9982
# Epoch 300/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0046 - val_accuracy: 0.9985
# Epoch 301/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0029 - val_accuracy: 0.9980
# Epoch 302/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9982
# Epoch 303/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9975 - val_loss: 0.0020 - val_accuracy: 0.9987
# Epoch 304/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0032 - val_accuracy: 0.9986
# Epoch 305/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0024 - val_accuracy: 0.9983
# Epoch 306/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9976 - val_loss: 0.0028 - val_accuracy: 0.9978
# Epoch 307/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0052 - val_accuracy: 0.9966
# Epoch 308/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0028 - val_accuracy: 0.9985
# Epoch 309/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9975 - val_loss: 0.0018 - val_accuracy: 0.9991
# Epoch 310/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9984
# Epoch 311/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.0029 - val_accuracy: 0.9985
# Epoch 312/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0023 - val_accuracy: 0.9980
# Epoch 313/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9982
# Epoch 314/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9979
# Epoch 315/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9980
# Epoch 316/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9978 - val_loss: 0.0037 - val_accuracy: 0.9982
# Epoch 317/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9982
# Epoch 318/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9981
# Epoch 319/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9973
# Epoch 320/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0037 - val_accuracy: 0.9980
# Epoch 321/500
# ...
# Epoch 395/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0027 - val_accuracy: 0.9981
# Epoch 396/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9979
# Epoch 397/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 398/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9979 - val_loss: 0.0042 - val_accuracy: 0.9980
# Epoch 399/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9984
# Epoch 400/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0022 - val_accuracy: 0.9991
# Epoch 401/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0054 - val_accuracy: 0.9981
# Epoch 402/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 0.0031 - val_accuracy: 0.9983
# Epoch 403/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0036 - val_accuracy: 0.9962
# Epoch 404/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9975 - val_loss: 0.0027 - val_accuracy: 0.9980
# Epoch 405/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0056 - val_accuracy: 0.9977
# Epoch 406/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9974 - val_loss: 0.0031 - val_accuracy: 0.9971
# Epoch 407/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0040 - val_accuracy: 0.9971
# Epoch 408/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9987
# Epoch 409/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0026 - val_accuracy: 0.9983
# Epoch 410/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0032 - val_accuracy: 0.9988
# Epoch 411/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0023 - val_accuracy: 0.9982
# Epoch 412/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0035 - val_accuracy: 0.9985
# Epoch 413/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9979 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 414/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9978 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 415/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0033 - val_accuracy: 0.9977
# Epoch 416/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9972 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 417/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0019 - val_accuracy: 0.9987
# Epoch 418/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.0021 - val_accuracy: 0.9985
# Epoch 419/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0051 - val_accuracy: 0.9973
# Epoch 420/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0027 - val_accuracy: 0.9977
# Epoch 421/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0044 - val_accuracy: 0.9977
# Epoch 422/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0019 - val_accuracy: 0.9982
# Epoch 423/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0030 - val_accuracy: 0.9985
# Epoch 424/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0034 - accuracy: 0.9975 - val_loss: 0.0018 - val_accuracy: 0.9981
# Epoch 425/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0035 - val_accuracy: 0.9978
# Epoch 426/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0030 - val_accuracy: 0.9982
# Epoch 427/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9979 - val_loss: 0.0049 - val_accuracy: 0.9973
# Epoch 428/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 429/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9979 - val_loss: 0.0057 - val_accuracy: 0.9974
# Epoch 430/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0068 - val_accuracy: 0.9963
# Epoch 431/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0025 - val_accuracy: 0.9982
# Epoch 432/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0033 - val_accuracy: 0.9984
# Epoch 433/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0022 - val_accuracy: 0.9984
# Epoch 434/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9979
# Epoch 435/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0022 - val_accuracy: 0.9984
# Epoch 436/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9978 - val_loss: 0.0031 - val_accuracy: 0.9986
# Epoch 437/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0035 - val_accuracy: 0.9978
# Epoch 438/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0025 - val_accuracy: 0.9984
# Epoch 439/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0022 - val_accuracy: 0.9986
# Epoch 440/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0030 - val_accuracy: 0.9972
# Epoch 441/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9974
# Epoch 442/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9979 - val_loss: 0.0029 - val_accuracy: 0.9987
# Epoch 443/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0022 - val_accuracy: 0.9982
# Epoch 444/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0036 - val_accuracy: 0.9972
# Epoch 445/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0026 - val_accuracy: 0.9986
# Epoch 446/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0024 - val_accuracy: 0.9978
# Epoch 447/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0034 - val_accuracy: 0.9982
# Epoch 448/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0061 - val_accuracy: 0.9981
# Epoch 449/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0030 - val_accuracy: 0.9975
# Epoch 450/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9979 - val_loss: 0.0043 - val_accuracy: 0.9977
# Epoch 451/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9978
# Epoch 452/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0023 - val_accuracy: 0.9978
# Epoch 453/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9981
# Epoch 454/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9976 - val_loss: 0.0026 - val_accuracy: 0.9990
# Epoch 455/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 456/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0049 - val_accuracy: 0.9965
# Epoch 457/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0049 - val_accuracy: 0.9982
# Epoch 458/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0031 - val_accuracy: 0.9971
# Epoch 459/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9979
# Epoch 460/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0027 - val_accuracy: 0.9985
# Epoch 461/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0033 - accuracy: 0.9976 - val_loss: 0.0020 - val_accuracy: 0.9986
# Epoch 462/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0028 - accuracy: 0.9979 - val_loss: 0.0048 - val_accuracy: 0.9971
# Epoch 463/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0024 - val_accuracy: 0.9985
# Epoch 464/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0032 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9980
# Epoch 465/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9975 - val_loss: 0.0033 - val_accuracy: 0.9980
# Epoch 466/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.0051 - val_accuracy: 0.9971
# Epoch 467/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0022 - val_accuracy: 0.9989
# Epoch 468/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9978 - val_loss: 0.0017 - val_accuracy: 0.9985
# Epoch 469/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0029 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9984
# Epoch 470/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0021 - val_accuracy: 0.9983
# Epoch 471/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0028 - accuracy: 0.9977 - val_loss: 0.0026 - val_accuracy: 0.9984
# Epoch 472/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0023 - val_accuracy: 0.9980
# Epoch 473/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0033 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9983
# Epoch 474/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9976 - val_loss: 0.0029 - val_accuracy: 0.9974
# Epoch 475/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9974 - val_loss: 0.0028 - val_accuracy: 0.9980
# Epoch 476/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9984
# Epoch 477/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9979 - val_loss: 0.0028 - val_accuracy: 0.9987
# Epoch 478/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0026 - val_accuracy: 0.9979
# Epoch 479/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0048 - val_accuracy: 0.9977
# Epoch 480/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.0032 - val_accuracy: 0.9977
# Epoch 481/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0020 - val_accuracy: 0.9983
# Epoch 482/500
# 73614/73614 [==============================] - 2s 25us/step - loss: 0.0030 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9987
# Epoch 483/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9975
# Epoch 484/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0059 - val_accuracy: 0.9965
# Epoch 485/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9975 - val_loss: 0.0029 - val_accuracy: 0.9983
# Epoch 486/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9978 - val_loss: 0.0024 - val_accuracy: 0.9980
# Epoch 487/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0020 - val_accuracy: 0.9980
# Epoch 488/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9979 - val_loss: 0.0019 - val_accuracy: 0.9985
# Epoch 489/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9974 - val_loss: 0.0024 - val_accuracy: 0.9988
# Epoch 490/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9976 - val_loss: 0.0021 - val_accuracy: 0.9990
# Epoch 491/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9978 - val_loss: 0.0025 - val_accuracy: 0.9975
# Epoch 492/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9976 - val_loss: 0.0027 - val_accuracy: 0.9980
# Epoch 493/500
# 73614/73614 [==============================] - 2s 27us/step - loss: 0.0031 - accuracy: 0.9980 - val_loss: 0.0023 - val_accuracy: 0.9984
# Epoch 494/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9980
# Epoch 495/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0039 - val_accuracy: 0.9978
# Epoch 496/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0029 - accuracy: 0.9978 - val_loss: 0.0034 - val_accuracy: 0.9977
# Epoch 497/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9976 - val_loss: 0.0019 - val_accuracy: 0.9985
# Epoch 498/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0032 - accuracy: 0.9977 - val_loss: 0.0019 - val_accuracy: 0.9986
# Epoch 499/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0031 - accuracy: 0.9975 - val_loss: 0.0030 - val_accuracy: 0.9975
# Epoch 500/500
# 73614/73614 [==============================] - 2s 26us/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.0023 - val_accuracy: 0.9984

# %%
plt.figure()
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
model_json = model.to_json()
with open("NN_model_NRLMSISE_1x1.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("NN_model_NRLMSISE_1x1.h5")
print("Saved model")
# Out:
# Saved model

# %%
mse_NN = np.zeros((1,pred_number))
mse_ROM = np.zeros((1,pred_number))

x_test_rom = np.copy(x_test)
x_test_NN = np.copy(x_test)
y_test_NN = np.copy(y_test)

prediction_NN = np.empty((15778,10))
prediction_POD = np.empty((15778,10))

for b in range(pred_number):
    y_pred = model_NN.predict(x_test_NN)
    y_test_NN = dens_data[split_15-pred_number+b:-pred_number-1+b,:]
    mse_num = 0
    for i in range(len(y_pred)):
        for j in range(len(y_pred[0])):
            mse_num += (y_pred[i][j] - y_test_NN[i][j])**2
    mse_NN[0][b] = mse_num/(y_pred.shape[0]*y_pred.shape[1])
    y_pred_error = abs(y_pred-y_test_NN)
    mse2 = np.zeros(y_pred_error.shape[0])
    for i1 in range(len(y_pred_error)):
        for j1 in range(len(y_pred_error[0])):
            mse2[i1] += y_pred_error[i1][j1]**2
        mse2[i1] = mse2[i1]/(y_pred_error.shape[1])
    
    sw_data_test = sw_data[split_15-pred_number+b:-pred_number-1+b,:]
    sw_data_test_append = sw_data[split_15-pred_number+1+b:-pred_number+b,:]
    sw_data_test = np.concatenate((sw_data_test, sw_data_test_append), axis = 1)
    x_test_NN = np.concatenate((y_pred, sw_data_test), axis=1)

print(mse_NN) 

for a in range(pred_number):
    #General
    y_test = dens_data[split_15-pred_number+a:-pred_number-1+a,:]
    sw_data_test = sw_data[split_15-pred_number-1+a:-pred_number-2+a,:]
    sw_data_test_append = sw_data[split_15-pred_number+a:-pred_number-1+a,:]
    sw_data_test = np.concatenate((sw_data_test, sw_data_test_append), axis = 1)
    if (a!= 0):
        x_test_rom = np.concatenate((x_test_rom, sw_data_test), axis=1)
    #x_test = np.concatenate((y_test, sw_data_test), axis=1)

    #ROM
    sw_data_test_ROM = x_test_rom[:,10:]
    dens_data_test_ROM = x_test_rom[:,:10]
    XfullPred = np.transpose(np.matmul(A,np.transpose(dens_data_test_ROM)) + np.matmul(B,np.transpose(sw_data_test_ROM)))
    #print(XfullPred.shape)
    prediction_POD = np.append(prediction_POD, XfullPred, axis =0)
    x_test_rom = np.copy(XfullPred)
    errFullPred = abs(XfullPred-y_test)
    mse_rom = 0 
    for x in range(len(errFullPred)):
        for y in range(len(errFullPred[0])):
            mse_rom += errFullPred[x][y]**2
    mse_ROM[0][a] = mse_rom/(errFullPred.shape[0]*errFullPred.shape[1])
    mse_rom2 = np.zeros(errFullPred.shape[0])
    for i2 in range(len(errFullPred)):
        for j2 in range(len(errFullPred[0])):
            mse_rom2[i2] += errFullPred[i2][j2]**2
        mse_rom2[i2] = mse_rom2[i2]/(errFullPred.shape[1])
    
print(mse_ROM) 

factor = np.zeros((pred_number))
for i in range(pred_number):
    factor[i] = mse_ROM[0][i]/mse_NN[0][i]
print(factor)

plt.figure(figsize = (15,6))
plt.plot(factor)
# Out:
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# (15778, 11)
# [[0.00382517 0.01035467 0.01882501 0.02895243 0.0401146  0.05203844
#   0.06467328 0.07771156 0.09105963 0.1047374  0.11859547 0.13261679
#   0.14686633 0.16133857 0.17612175 0.19137865 0.20713753 0.22346587
#   0.24047162 0.25814175 0.27646934 0.29548699 0.31511942 0.33530857]]
# [[0.04913643 0.16366072 0.32413406 0.52294262 0.73786752 0.95864782
#   1.18683673 1.40686479 1.61378683 1.81316726 1.99341812 2.15235767
#   2.29702036 2.42213816 2.53050363 2.63313363 2.72465103 2.80736048
#   2.89132214 2.97100089 3.0481735  3.13223959 3.21716386 3.30417155]]
# [12.84556756 15.80550138 17.21827161 18.06213444 18.39398913 18.42191684
#  18.35126912 18.10367556 17.72230801 17.31155442 16.8085513  16.22990298
#  15.6402112  15.01276566 14.36792269 13.75876355 13.15382592 12.56281556
#  12.02354841 11.50918377 11.02535831 10.60026225 10.20934816  9.85412208]
# (15778, 10)
# (394450, 10)

# %%
plt.figure(figsize = (15,6))
#plt.title("NRLMSISE 1997-2008: DMDc/NN MSE for 24 Hours Time Series using 1x1 Autoencoder")
plt.plot(range(1,1+len(factor)),factor, label = "DMDc/NN MSE")
#ratio.set_xlim(1,len(factor))
plt.grid()
plt.minorticks_on()
#ax.grid(which='minor', linestyle=':', linewidth='0.3', color='black')
plt.legend(fontsize=14)
plt.xlabel("Hours", fontsize=14)
plt.ylabel("DMDc/NN", fontsize=14)
#plt.savefig('1x1_AE_DMDc/NN_Ratio.png')  
#plt.show()


plt.figure(figsize = (15,6))
#plt.title("NRLMSISE 1997-2008: Comparison of MSE for 24 Hours Time Series using 1x1 Autoencoder")
plt.plot(range(1,1+len(factor)),mse_NN.T, label = "MSE for NN")
#norm_mse.set_xlim(1,len(factor))
plt.plot(range(1,1+len(factor)),mse_ROM.T, label = "MSE for DMDc")
plt.grid()
plt.minorticks_on()
#ax.grid(which='minor', linestyle=':', linewidth='0.', color='black')
plt.xlabel("Hours",fontsize=14)
plt.ylabel("MSE",fontsize=14)
plt.legend(fontsize=14)
#plt.savefig('1x1_AE_DMDc_NN_MSE.png')
#plt.show()

# %%
with open('NN_model_NRLMSISE_1x1.json','r') as f:
    model_NN_json = json.load(f)
    model_NN_json = json.dumps(model_NN_json)
    model_NN_json = str(model_NN_json)

model_NN = model_from_json(model_NN_json)
model_NN.load_weights('NN_model_NRLMSISE_1x1.h5')
model_NN.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 120)               3960
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 120)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                4840
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 40)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                820
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 20)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                210
# =================================================================
# Total params: 9,830
# Trainable params: 9,830
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_test_NN = x_test[0,:]
x_test_NN= np.reshape(x_test_NN, (1, 32))
x_test_rom = np.reshape(x_test[0,:10], (1, 10))

NN_prediction = None
for b in range(pred_number):
    y_pred = model_NN.predict(x_test_NN)
    if b == 0:
        NN_prediction = y_pred
    else:
        NN_prediction = np.append(NN_prediction, y_pred, axis = 0)
    sw_data_test = np.reshape(sw_data[b,:], (1,11))
    sw_data_test_append = np.reshape(sw_data[b+1,:],(1,11))
    sw_data_test = np.concatenate((sw_data_test, sw_data_test_append), axis = 1)
    x_test_NN = np.concatenate((y_pred, sw_data_test), axis=1)
    
DMDc_prediction = None
for a in range(pred_number):
    #General
    sw_data_test = np.reshape(sw_data[a,:], (1,11))
    sw_data_test_append = np.reshape(sw_data[a+1,:], (1,11))
    sw_data_test = np.concatenate((sw_data_test, sw_data_test_append), axis = 1)
    x_test_rom = np.transpose(np.matmul(A,np.transpose(x_test_rom)) + np.matmul(B,np.transpose(sw_data_test)))
    if not a:
        DMDc_prediction = x_test_rom
    else:
        DMDc_prediction = np.append(DMDc_prediction, x_test_rom, axis = 0)

# %%
#print(NN_prediction)
#print(DMDc_prediction)
nndecoded = None
DMDcdecoded = None
for i in range(1,25):
    nn_data = NN_prediction[i-1:i,:]
    decoded_nn = decoder_model_1x1.predict(nn_data)
    DMDc_data = DMDc_prediction[i-1:i,:]
    decoded_DMDc = decoder_model_1x1.predict(DMDc_data)
    if i == 1:
        nndecoded = decoded_nn
        DMDcdecoded = decoded_DMDc
    else:
        nndecoded = np.append(nndecoded, decoded_nn, axis = 0)
        DMDcdecoded = np.append(DMDcdecoded, decoded_DMDc, axis = 0)
print(nndecoded.shape)
print(DMDcdecoded.shape)
# Out:
# (24, 17280)
# (24, 17280)

# %%
MSISEstd = np.std(xdata_1, keepdims=True)
MSISEmean = np.mean(xdata_1, keepdims=True)

# %%
nndecoded = nndecoded*MSISEstd + MSISEmean
DMDcdecoded = DMDcdecoded*MSISEstd + MSISEmean
tens = np.full((24,17280), 10)
nndecoded = np.power(tens, nndecoded)
DMDcdecoded = np.power(tens, DMDcdecoded)

# %%
"""Plot densities"""
nndecoded_1 = np.reshape(nndecoded[0,:], (24, 20, 36))
altitude_18 = nndecoded_1[:,:,18]
CS = plt.contourf(altitude_18)
cbar = plt.colorbar(CS)
cbar.ax.set_ylabel('verbosity coefficient')

# %%
plt.figure()
plt.plot(nndecoded[:,0])
plt.plot(nndecoded[:,1])
plt.plot(nndecoded[:,2])
print(nndecoded[:,2].shape)


plt.figure()
plt.plot(DMDcdecoded[:,0])
plt.plot(DMDcdecoded[:,1])
plt.plot(DMDcdecoded[:,2])

print(xdata[split_15:split_15+1,:].shape)

#plt.figure()
#plt.plot(xdata[split_15:split_15+1,:])

# %%
decoded_NN = decoder_model_1x1.predict(prediction_NN)
plt.plot(decoded_NN[:, 10])
#decoded_POD = decoder_model_1x1.predict(prediction_POD)

# %%
plt.plot(decoded_NN[:, 0])

# %%
print(decoded_NN.shape)
plt.plot(decoded_NN[:,17279])
# Out:
# (31556, 17280)

# %%
decoded_NN = decoded_NN*np.std(xdata_1, keepdims=True) + np.mean(xdata_1, keepdims=True)

#xmat = (xdata_1 - np.mean(xdata_1, keepdims=True)) / np.std(xdata_1, keepdims=True)

# %%
tens = np.full((15778,17280), 10)
decoded_NN = np.power(tens, decoded_NN)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-400428bc2395> in <module>
#       1 tens = np.full((15778,17280), 10)
# ----> 2 decoded_NN = np.power(tens, decoded_NN)
#
# ValueError: operands could not be broadcast together with shapes (15778,17280) (31556,17280)

# %%
plt.figure()
plt.plot(decoded_NN[:,0])
plt.figure()
plt.plot(xdata[:,0])
